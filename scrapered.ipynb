# %%
! pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Using cached google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews_all

us_reviews = reviews_all('com.qianfan.aihomework',
                         sleep_milliseconds=0, lang='id',
                         country='id', sort=Sort.NEWEST,
                         filter_score_with=None)

# %%
df_busu = pd.DataFrame(np.array(us_reviews), columns=['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu
# Out:
#                                   reviewId                      userName  \
# 0     3b9645ef-a99e-4e64-a5c9-a54824740ea8  Dominikus Tripuspa Mahardika
# 1     2940b09a-e49d-42d2-b5e3-b1b83e2cde3a                    Kayla _UwU
# 2     4fc8d346-fb87-429d-9eee-0a80976f171e                 zahrana putri
# 3     3a99ef5a-58e8-4ac3-a39a-d4ecf87c40da                    SAMURAI ID
# 4     abf69131-96f1-4259-80cf-f44832cbb7aa                     Rian Rian
# ...                                    ...                           ...
# 5649  0feac083-9506-466e-b657-4f8353e78fd8                   Bocil ep Ep
# 5650  14fb1e4a-2a2d-479c-b69e-009e5b541c46                  Ersa Pratiwi
# 5651  871bbbd8-b40d-4673-822e-f2720ba8dd09                  Fadhlan Arsy
# 5652  8040f071-c83e-4d14-8ba4-ee2c61ff0311                Angga official
# 5653  49d6d143-fde6-4bd2-af4e-e0d8ab59558c                   Yeni Bawell
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                 ...
# 5649  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5650  https://play-lh.googleusercontent.com/a-/ALV-U...
# 5651  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5652  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5653  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0     Aplikasi yang sangat bagus, keren dan canggih ...      5            301
# 1     Aplikasi nya berguna banget, saya punya tugas ...      5            429
# 2     Terkadang susah, saat sudah memfotonya selalu ...      4            988
# 3     Apk paling berguna 99% pasti ada semua jawaban...      5            758
# 4     Aplikasi nya bagus,mudah dipakai,aplikasi yang...      5            665
# ...                                                 ...    ...            ...
# 5649                                                  👍      5              0
# 5650                      ✅👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍      5              0
# 5651                              Sangat bagus👍👍👍👍👍👍👍👍👍      5              0
# 5652                                          Bagus🙏🙏🙏🙏      5              0
# 5653                                          👍👍👍👍bagus      5              0
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                   1.8.4 2023-10-14 17:40:11         None       NaT
# 1                   1.7.0 2023-10-10 18:02:32         None       NaT
# 2                   1.6.3 2023-09-12 15:47:15         None       NaT
# 3                   1.6.3 2023-09-11 09:28:34         None       NaT
# 4                   1.5.1 2023-08-28 19:43:17         None       NaT
# ...                   ...                 ...          ...       ...
# 5649                 None 2023-08-27 22:59:54         None       NaT
# 5650                 None 2023-10-11 17:34:18         None       NaT
# 5651                 None 2023-09-28 16:45:52         None       NaT
# 5652                 None 2023-09-24 13:49:09         None       NaT
# 5653                 None 2023-10-03 17:51:15         None       NaT
#
#      appVersion
# 0         1.8.4
# 1         1.7.0
# 2         1.6.3
# 3         1.6.3
# 4         1.5.1
# ...         ...
# 5649       None
# 5650       None
# 5651       None
# 5652       None
# 5653       None
#
# [5654 rows x 11 columns]

# %%
len(df_busu.index)
# Out:
# 5653

# %%
df_busu[['userName','score','at','content']]
# Out:
#                           userName  score                  at  \
# 0     Dominikus Tripuspa Mahardika      5 2023-10-14 17:40:11
# 1                       Kayla _UwU      5 2023-10-10 18:02:32
# 2                    zahrana putri      4 2023-09-12 15:47:15
# 3                       SAMURAI ID      5 2023-09-11 09:28:34
# 4                        Rian Rian      5 2023-08-28 19:43:17
# ...                            ...    ...                 ...
# 5648                   Bocil ep Ep      5 2023-08-27 22:59:54
# 5649                  Ersa Pratiwi      5 2023-10-11 17:34:18
# 5650                  Fadhlan Arsy      5 2023-09-28 16:45:52
# 5651                Angga official      5 2023-09-24 13:49:09
# 5652                   Yeni Bawell      5 2023-10-03 17:51:15
#
#                                                 content
# 0     Aplikasi yang sangat bagus, keren dan canggih ...
# 1     Aplikasi nya berguna banget, saya punya tugas ...
# 2     Terkadang susah, saat sudah memfotonya selalu ...
# 3     Apk paling berguna 99% pasti ada semua jawaban...
# 4     Aplikasi nya bagus,mudah dipakai,aplikasi yang...
# ...                                                 ...
# 5648                                                  👍
# 5649                      ✅👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍
# 5650                              Sangat bagus👍👍👍👍👍👍👍👍👍
# 5651                                          Bagus🙏🙏🙏🙏
# 5652                                          👍👍👍👍bagus
#
# [5653 rows x 4 columns]

# %%
my_df = df_busu[['userName','score','at','content']]

# %%
my_df.to_csv('scrapped_data.csv', index=False)
